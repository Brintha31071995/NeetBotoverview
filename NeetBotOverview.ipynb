# %%
import time
import pandas as pd
import numpy as np
import sqlite3
import cv2
import matplotlib.pyplot as plt

print("Hi My dear future Health Care Warriors"+'\U0001F929'+"! Welcome to have knowledge about your first step of Battle -Neet!")
print("I am Nida to assist you about Neet Exam information!")
print("")
print("Please enter the below requested information for our security purpose")
x= str(input("Please Enter Name:"))
y=str(input("Please Enter Email:"))
z=str(input("Please Enter Phone Number:"))
def is_valid_mobile_number(z):
    if len(z) == 10 and z.isdigit():
        return True
    else:
        return False

def is_valid_email(y):
    if '@' in y and '.' in y:
        return True
    else:
        return False
print("Dear "+ x + " Welcome to our portal"+'\U0001F642'+"I am here to assist you further!")    
# Validate the mobile number
while not is_valid_mobile_number(z):
    print("Invalid mobile number. Please enter a 10-digit number.")
    z = input("Enter a mobile number: ")

# Validate the email
while not is_valid_email(y):
    print("Invalid email address. Please enter a valid email.")
    y = input("Enter an email address: ")

time_limit = 10
start_time = time.time()
end_time = start_time + time_limit
while time.time() < end_time:
           time.sleep(1)           
    
           words_to_remove = ["what", "is", "who","when","you","how","which","do","can","i","are","the","we","they","has","many","have","does","why","whose","where","is","howmany","much","was"]    
           
           c = input("Please let me know how can I assist you: ")
           
           words = c.split()
           filtered_words = [word for word in words if word.lower() not in words_to_remove]
           result = " ".join(filtered_words)
           lower=result.lower()
           b=lower

           data={}
           def read(i):
                filename = 'file' + str(i) + '.txt'
                with open(filename, "r") as file:
                  data['g' + str(i)]=file.read()
                  a=data['g'+str(i)]
                  print(a)
                  return a
           #what is neet      
           if b in ['neet exam','neetexam','neet','neet xam','niet exam','niet xam','explain neet exam','detail about neet exam','overview about neet exam','let me know something about neet exam','information about neet exam','info about neet exam','explain neet','detail about neet','overview about neet','let me know something about neet','information about neet','info about neet','tell me something about neet exam','tell me something about neet']:
             x=read(1)
           elif b in ['neet full form','full form','niet full farm','full name of neet']:
             x=read(2)
           else:
             print("Sorry we are unable to find the suitable result for you! Please check on the below and find what you are looking for !")
             time.sleep(1)   
             while True:    
                 print("")#main menu
                 print("Could you please choose the Topic which is relevent to you "+'\U0001F914'+"?") 
                 print("")
                 print("1.General Information")
                 print("2.Application Process")
                 print("3.Study Plan/Syllabus/weightage")
                 print("4.Exam Overview")
                 print("5.Exam Center/Admit Card")
                 print("6.Its About Exam Day")
                 print("7.Marking scheme & Result")
                 print("8.Counselling & Admission")
                 print("9.Exit and Close the Chat")
                 print("")
                 b = input("I am waiting for your response "+'\U0001F643'+"....Please let me know the choosen topic to know more....")
                 print("")#submenu1
                 if b in ['1','general information','general info', 'genral information','generel information']:
                   while True:
                      print("")  
                      print("1.What is NEET?")
                      print("2.What are the courses under Neet?")
                      print("3.Countries / Regions")
                      print("4.Qualifications")
                      print("5.Languages")
                      print("6.Attempts")
                      print("7.Advantage")
                      print("8.Purpose")
                      print("9.Eligibility-India")
                      print("10.Eligibility- Outside India")
                      print("11.Age Limit")
                      print("")
    
                      b1 =int(input("Which information you are looking for "+'\U0001F914'+"...."))
                      if b1 ==1:
                         with open("Whatisneet.txt", "r") as file:
                          print(file.read())
                          repeat = input("Do you want to continue next topis? (y/n): ")
                          if repeat.lower() != 'y':
                           break  
                      elif b1 ==2:
                          d = pd.read_excel('CourseAfterNeet.xlsx')
                          print(d)
                          repeat = input("Do you want to continue next topis? (y/n): ")
                          if repeat.lower() != 'y':
                           break
                      elif b1 ==3:  
                           with open("Regionsandcountry.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break
                      elif b1 ==4:  
                           with open("nq.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break  
                      elif b1 ==5:  
                           with open("Languages.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break
                      elif b1 ==6:  
                           with open("NumberofAttempts.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break 
                      elif b1 ==7:  
                           with open("Advantages.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break
                      elif b1 ==8:  
                           with open("Purpose.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break
                      elif b1 ==9:  
                           with open("Eligiblity.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break
                      elif b1 ==10:  
                           with open("EligibilityNRI.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break
                      elif b1 ==11:  
                           with open("AgeCriteria.txt", "r") as file:
                            print(file.read())
                            repeat = input("Do you want to continue next topis? (y/n): ")
                            if repeat.lower() != 'y':
                             break                
                      else:
                          repeat = input("Please choose the correct input...Do you want to see the General Information list again"+'\U0001F643'+"? (y/n): ")
                          if repeat.lower() != 'y':
                           break
                   print("Loading....")
                   time.sleep(2)
                   repeat = input("Do you want to proceed further?(y/n): ")
                   if repeat.lower() != 'y':
                     break #Need to check if we have option without repeat statement 
                    #submenu2
                 else:
                        print("Thank you for contacting"+'\U0001F642'+"! We will get back to you with the updates in future!")
                        V = str(input("Please let us know your valueable Feedback here for our improvement \U0001F642...Thank You!: "))  

                 a=np.array([x])
                 b=np.array([y])
                 c=np.array([z])
                 e=np.array([V]) 
                 frame={ "Name":a, "Email":b, "Phone Number":c, "Feedback":e}
                 d = pd.DataFrame(frame)
                 db="Nida.sqlite"
                 conn=sqlite3.connect(db)
                 d.to_sql(name='Users', con=conn,if_exists='append',index=False)
                 conn.close()  
                 a=np.array([a1])
                 b=np.array([b1])
                 framee={ "data":a1, "data2":b1}
                 d1 = pd.DataFrame(frame)
                 db="Nida1.sqlite"
                 conn=sqlite3.connect(db)
                 d1.to_sql(name='Users', con=conn,if_exists='append',index=False)
                 conn.close()
# Out:
# Hi My dear future Health Care Warriors🤩! Welcome to have knowledge about your first step of Battle -Neet!
# I am Nida to assist you about Neet Exam information!
#
# Please enter the below requested information for our security purpose
# Please Enter Name: br
# Please Enter Email: gh@.
# Please Enter Phone Number: 9384732938
# Dear br Welcome to our portal🙂I am here to assist you further!
# Please let me know how can I assist you:  mmm
# Sorry we are unable to find the suitable result for you! Please check on the below and find what you are looking for !
#
# Could you please choose the Topic which is relevent to you 🤔?
#
# 1.General Information
# 2.Application Process
# 3.Study Plan/Syllabus/weightage
# 4.Exam Overview
# 5.Exam Center/Admit Card
# 6.Its About Exam Day
# 7.Marking scheme & Result
# 8.Counselling & Admission
# 9.Exit and Close the Chat
# I am waiting for your response 🙃....Please let me know the choosen topic to know more.... 1
# 1.What is NEET?
# ...
